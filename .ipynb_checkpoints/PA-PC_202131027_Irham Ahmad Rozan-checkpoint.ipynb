# %% [markdown]
# # 202131027_Irham Ahmad Rozan

# %% [markdown]
# ## Import Library

# %%
import cv2 as cv
import numpy as np
from PIL import Image
from rembg import remove
from matplotlib import pyplot as plt

# %% [markdown]
# ## Read and Show Image

# %%
image = cv.imread ("output.png")
rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

plt.imshow(rgb)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %% [markdown]
# ## Convert Image to Binary with Thresholding Method

# %%
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(gray, 2, 255, cv.THRESH_BINARY_INV + cv.THRESH_OTSU)

# %% [markdown]
# ## Contour from Binary

# %%
contours, hierarchy = cv.findContours(thresh, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# ## Mask

# %%
mask = np.zeros(image.shape[:2], np.uint8)

# %% [markdown]
# ## Contour Image on Mask

# %%
cv.drawContours(mask, contours, -1, (255), thickness=cv.FILLED)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %% [markdown]
# ## Merge the Original Images with Masks Using the Bitwise AND Operator

# %%
rmv = cv.bitwise_and(image, image, mask=mask)

# %%
img = cv.cvtColor(rmv, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Remove Background

# %%
output = remove(img)

plt.imshow(output)
plt.title('Backgorund Removed')
# Out:
# Text(0.5, 1.0, 'Backgorund Removed')

# %%
fig, axs = plt.subplots(1,2, figsize = (10,10))
ax = axs.ravel()

ax[0].imshow(image)
ax[0].set_title("Original Image")
ax[1].imshow(output)
ax[1].set_title("After Background Removed")
# Out:
# Text(0.5, 1.0, 'After Background Removed')

# %%
changeColor = cv.cvtColor(output, cv.COLOR_BGR2RGB)
printImage = remove(changeColor)
cv.imwrite("output.png", printImage)
# Out:
# True
